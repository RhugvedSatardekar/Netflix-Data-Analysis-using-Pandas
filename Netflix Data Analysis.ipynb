# %%
import pandas as pd

# %%
netflix = pd.read_csv('file.csv',parse_dates=['Release_Date'])

# %%
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7784        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                NaN                                            Nasty C
# 7787                NaN                         Adriano Zumbo, Rachel Khoo
# 7788           Sam Dunn                                                NaN
#
#                                                 Country        Release_Date  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7785                                              India       March 2, 2019
# 7786                                                NaN  September 25, 2020
# 7787                                          Australia    October 31, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      Rating   Duration                                               Type  \
# 0     TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     TV-MA     93 min                       Dramas, International Movies
# 2         R     78 min                Horror Movies, International Movies
# 3     PG-13     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4     PG-13    123 min                                             Dramas
# ...     ...        ...                                                ...
# 7784  TV-MA     99 min                       Dramas, International Movies
# 7785  TV-14    111 min     Dramas, International Movies, Music & Musicals
# 7786  TV-MA     44 min  Documentaries, International Movies, Music & M...
# 7787  TV-PG   1 Season                 International TV Shows, Reality TV
# 7788  TV-MA     90 min                    Documentaries, Music & Musicals
#
#                                             Description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7784  When Lebanon's Civil War deprives Zozo of his ...
# 7785  A scrappy but poor boy worms his way into a ty...
# 7786  In this documentary, South African rapper Nast...
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...
#
# [7789 rows x 11 columns]

# %%
netflix.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 7.5 MB

# %%
netflix.describe()
# Out:
#        Show_Id Category     Title                Director                Cast  \
# count     7789     7789      7789                    5401                7071
# unique    7787        2      7787                    4050                6831
# top       s684    Movie  Backfire  Raúl Campos, Jan Suter  David Attenborough
# freq         2     5379         2                      18                  18
#
#               Country     Release_Date Rating  Duration           Type  \
# count            7282             7779   7782      7789           7789
# unique            681             1565     14       216            492
# top     United States  January 1, 2020  TV-MA  1 Season  Documentaries
# freq             2556              118   2865      1608            334
#
#                                               Description
# count                                                7789
# unique                                               7769
# top     Multiple women report their husbands as missin...
# freq                                                    3

# %%
netflix.head(10)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 8  Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...          India
# 9  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          India
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
# 5       July 1, 2017  TV-MA   1 Season
# 6       June 1, 2020  TV-MA     95 min
# 7   November 1, 2019      R    119 min
# 8      April 1, 2019  TV-14    118 min
# 9  December 15, 2017  TV-MA    143 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
# 5    International TV Shows, TV Dramas, TV Mysteries
# 6                Horror Movies, International Movies
# 7                                             Dramas
# 8                Horror Movies, International Movies
# 9     Horror Movies, International Movies, Thrillers
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...
# 5  A genetics professor experiments with a treatm...
# 6  After an awful accident, a couple admitted to ...
# 7  After one of his high school students attacks ...
# 8  When a doctor goes missing, his psychiatrist w...
# 9  An architect and his wife move into a castle t...

# %%
netflix.tail(5)
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7785                                              India       March 2, 2019
# 7786                                                NaN  September 25, 2020
# 7787                                          Australia    October 31, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      Rating  Duration                                               Type  \
# 7784  TV-MA    99 min                       Dramas, International Movies
# 7785  TV-14   111 min     Dramas, International Movies, Music & Musicals
# 7786  TV-MA    44 min  Documentaries, International Movies, Music & M...
# 7787  TV-PG  1 Season                 International TV Shows, Reality TV
# 7788  TV-MA    90 min                    Documentaries, Music & Musicals
#
#                                             Description
# 7784  When Lebanon's Civil War deprives Zozo of his ...
# 7785  A scrappy but poor boy worms his way into a ty...
# 7786  In this documentary, South African rapper Nast...
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...

# %%
netflix.shape
# Out:
# (7789, 11)

# %%
netflix.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
netflix.size # no of cells
# Out:
# 85679

# %%
netflix.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### Remove Duplicate Records

# %%
netflix[netflix.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
netflix.drop_duplicates(inplace=True)

# %% [markdown]
# ### IF null values in dataframe show it in Heat Map

# %%
netflix.isna().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sal
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import seaborn as sal
#
# File c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages\seaborn\__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages\seaborn\relational.py:21
#      13 from .utils import (
#      14     adjust_legend_subtitles,
#      15     _default_color,
#    (...)
#      18     _scatter_legend_artist,
#      19 )
#      20 from ._compat import groupby_apply_include_groups
# ---> 21 from ._statistics import EstimateAggregator, WeightedAggregator
#      22 from .axisgrid import FacetGrid, _facet_docs
#      23 from ._docstrings import DocstringComponents, _core_docs
#
# File c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages\seaborn\_statistics.py:32
#      30 import pandas as pd
#      31 try:
# ---> 32     from scipy.stats import gaussian_kde
#      33     _no_scipy = False
#      34 except ImportError:
#
# File c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\__init__.py:441
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     438
#     439 """
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# File c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages\scipy\stats\stats.py:37
#      34 import numpy as np
#      35 from numpy import array, asarray, ma
# ---> 37 from scipy.spatial.distance import cdist
#      38 from scipy.ndimage import measurements
#      39 from scipy._lib._util import (check_random_state, MapWrapper,
#      40                               rng_integers, float_factorial)
#
# File c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages\scipy\spatial\__init__.py:96
#       1 """
#       2 =============================================================
#       3 Spatial algorithms and data structures (:mod:`scipy.spatial`)
#    (...)
#      93
#      94 """
# ---> 96 from .kdtree import *
#      97 from .ckdtree import *
#      98 from .qhull import *
#
# File c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages\scipy\spatial\kdtree.py:5
#       3 import numpy as np
#       4 import warnings
# ----> 5 from .ckdtree import cKDTree, cKDTreeNode
#       7 __all__ = ['minkowski_distance_p', 'minkowski_distance',
#       8            'distance_matrix',
#       9            'Rectangle', 'KDTree']
#      12 def minkowski_distance_p(x, y, p=2):
#
# File ckdtree.pyx:1, in init scipy.spatial.ckdtree()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
import numpy as np

# %%
import matplotlib as mpl

# %%
# !pip uninstall numpy seaborn -y
# !pip install numpy seaborn
# Out:
# Found existing installation: numpy 2.0.0
# Uninstalling numpy-2.0.0:
#   Successfully uninstalled numpy-2.0.0
# Found existing installation: seaborn 0.13.2
# Uninstalling seaborn-0.13.2:
#   Successfully uninstalled seaborn-0.13.2
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Rhugved\AppData\Local\Programs\Python\Python39\Lib\site-packages\~-mpy.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Rhugved\AppData\Local\Programs\Python\Python39\Lib\site-packages\~~mpy'.
# You can safely remove it manually.
# Collecting numpy
#   Using cached numpy-2.0.0-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: pandas>=1.2 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from seaborn) (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.37.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (20.9)
# Requirement already satisfied: pillow>=8 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.2->seaborn) (2022.5)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# Using cached numpy-2.0.0-cp39-cp39-win_amd64.whl (16.5 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: numpy, seaborn
# Successfully installed numpy-2.0.0 seaborn-0.13.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 2.0.0 which is incompatible.

# %%
#import seaborn as sns

# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\rhugved\appdata\local\programs\python\python39\lib\site-packages (1.23.0)

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.0.0'

# %% [markdown]
# ### For house of cards, what is the showID and who is the director of this show

# %%
netflix[['Show_Id','Director']][netflix.Title == 'House of Cards']
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# ### In which Year highest number of TV shows & movies were released

# %%
netflix.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7785                                              India       March 2, 2019
# 7786                                                NaN  September 25, 2020
# 7787                                          Australia    October 31, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      Rating  Duration                                               Type  \
# 7784  TV-MA    99 min                       Dramas, International Movies
# 7785  TV-14   111 min     Dramas, International Movies, Music & Musicals
# 7786  TV-MA    44 min  Documentaries, International Movies, Music & M...
# 7787  TV-PG  1 Season                 International TV Shows, Reality TV
# 7788  TV-MA    90 min                    Documentaries, Music & Musicals
#
#                                             Description
# 7784  When Lebanon's Civil War deprives Zozo of his ...
# 7785  A scrappy but poor boy worms his way into a ty...
# 7786  In this documentary, South African rapper Nast...
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...

# %%
netflix.drop('Year',axis=1,inplace=True)

# %%
netflix['Date_New'] = pd.to_datetime(netflix['Release_Date'],format='mixed')

# %%
netflix.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_New        datetime64[ns]
# dtype: object

# %%
netflix.Date_New.dt.year.astype
# Out:
# <bound method NDFrame.astype of 0       2020.0
# 1       2016.0
# 2       2018.0
# 3       2017.0
# 4       2020.0
#          ...
# 7784    2020.0
# 7785    2019.0
# 7786    2020.0
# 7787    2020.0
# 7788    2020.0
# Name: Date_New, Length: 7787, dtype: float64>

# %%
netflix['Year'] = netflix.Date_New.dt.year

# %%
netflix['Year'] = netflix.Year.astype(str)

# %%
netflix['Year'] = netflix.Year.str.replace('.0','')

# %%
netflix.drop('Release_Date',axis=1,inplace=True)

# %%
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7784        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                NaN                                            Nasty C
# 7787                NaN                         Adriano Zumbo, Rachel Khoo
# 7788           Sam Dunn                                                NaN
#
#                                                 Country Rating   Duration  \
# 0                                                Brazil  TV-MA  4 Seasons
# 1                                                Mexico  TV-MA     93 min
# 2                                             Singapore      R     78 min
# 3                                         United States  PG-13     80 min
# 4                                         United States  PG-13    123 min
# ...                                                 ...    ...        ...
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...  TV-MA     99 min
# 7785                                              India  TV-14    111 min
# 7786                                                NaN  TV-MA     44 min
# 7787                                          Australia  TV-PG   1 Season
# 7788              United Kingdom, Canada, United States  TV-MA     90 min
#
#                                                    Type  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7784                       Dramas, International Movies
# 7785     Dramas, International Movies, Music & Musicals
# 7786  Documentaries, International Movies, Music & M...
# 7787                 International TV Shows, Reality TV
# 7788                    Documentaries, Music & Musicals
#
#                                             Description   Date_New  Year
# 0     In a future where the elite inhabit an island ... 2020-08-14  2020
# 1     After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2     When an army recruit is found dead, his fellow... 2018-12-20  2018
# 3     In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017
# 4     A brilliant group of students become card-coun... 2020-01-01  2020
# ...                                                 ...        ...   ...
# 7784  When Lebanon's Civil War deprives Zozo of his ... 2020-10-19  2020
# 7785  A scrappy but poor boy worms his way into a ty... 2019-03-02  2019
# 7786  In this documentary, South African rapper Nast... 2020-09-25  2020
# 7787  Dessert wizard Adriano Zumbo looks for the nex... 2020-10-31  2020
# 7788  This documentary delves into the mystique behi... 2020-03-01  2020
#
# [7787 rows x 12 columns]

# %%
df = pd.DataFrame(netflix.pivot_table(index='Year',columns='Category',values='Show_Id',aggfunc='count'))

# %%
netflix[['Year','Category','Show_Id']].groupby(['Year','Category']).count().sort_values('Show_Id',ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Year,Category'>

# %%
netflix.Year.value_counts()
# Out:
# Year
# 2019    2153
# 2020    2009
# 2018    1685
# 2017    1225
# 2016     443
# 2021     117
# 2015      88
# 2014      25
# 2011      13
# 2013      11
# nan       10
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# Name: count, dtype: int64

# %% [markdown]
# ### How many movies and TV shows in dataset

# %%
netflix['Category'].value_counts()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: count, dtype: int64

# %%
netflix.groupby(['Year'])['Category'].count()
# Out:
# Year
# 2008       2
# 2009       2
# 2010       1
# 2011      13
# 2012       3
# 2013      11
# 2014      25
# 2015      88
# 2016     443
# 2017    1225
# 2018    1685
# 2019    2153
# 2020    2009
# 2021     117
# nan       10
# Name: Category, dtype: int64

# %%
seaborn.countplot(netflix.Category)

# %% [markdown]
# ### Show all the movies relesed in Year 2000

# %%
netflix.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# 2     78 min                Horror Movies, International Movies
# 3     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4    123 min                                             Dramas
#
#                                          Description   Date_New  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017
# 4  A brilliant group of students become card-coun... 2020-01-01  2020

# %%
Movies_2020 = pd.DataFrame(netflix['Title'][(netflix.Year == '2020') & (netflix.Category == 'Movie')]).reset_index(drop=True)

# %%
Movies_2020
# Out:
#                                         Title
# 0                                          21
# 1                                         122
# 2                                        3022
# 3                                      #Alive
# 4               #AnneFrank - Parallel Stories
# ...                                       ...
# 1307                                Zaki Chan
# 1308                                     Zoom
# 1309                                     Zozo
# 1310                        Zulu Man in Japan
# 1311  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
# [1312 rows x 1 columns]

# %% [markdown]
# ### Show the Titles of TV Shows released in India only

# %%
Indian_TV_Shows = pd.DataFrame(netflix['Title'][(netflix.Country == 'India') & (netflix.Category == 'TV Show')]).reset_index(drop= True)

# %%
Indian_TV_Shows.Title.describe()
# Out:
# count                               71
# unique                              71
# top       21 Sarfarosh: Saragarhi 1897
# freq                                 1
# Name: Title, dtype: object

# %% [markdown]
# ### Show the top 10 Directors who gave the highest number of TV Shows and Movies to Netflix

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# 2     78 min                Horror Movies, International Movies
# 3     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4    123 min                                             Dramas
#
#                                          Description   Date_New  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017
# 4  A brilliant group of students become card-coun... 2020-01-01  2020

# %%
netflix.Director.value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Johnnie To                 8
# Name: count, dtype: int64

# %% [markdown]
# ### Show all the records where category is Movie and Type is Comedies or country is UK

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# 2     78 min                Horror Movies, International Movies
# 3     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4    123 min                                             Dramas
#
#                                          Description   Date_New  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017
# 4  A brilliant group of students become card-coun... 2020-01-01  2020

# %%
df=pd.DataFrame(netflix[((netflix.Category == 'Movie') & (netflix.Type.str.contains('[Cc]omed[yies]',regex=True,na=False))) ])

# %%
netflix.Type.str.contains('[comedy]',regex=True)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 7784    True
# 7785    True
# 7786    True
# 7787    True
# 7788    True
# Name: Type, Length: 7787, dtype: bool

# %%
df.Type.unique()
# Out:
# array(['Comedies, Dramas, Independent Movies', 'Comedies',
#        'Comedies, Romantic Movies',
#        'Comedies, Dramas, International Movies',
#        'Comedies, International Movies',
#        'Comedies, International Movies, Romantic Movies',
#        'Action & Adventure, Comedies, International Movies',
#        'Comedies, Dramas', 'Action & Adventure, Comedies',
#        'Children & Family Movies, Comedies', 'Comedies, LGBTQ Movies',
#        'Comedies, Dramas, Romantic Movies',
#        'Comedies, Independent Movies, Thrillers',
#        'Comedies, International Movies, Music & Musicals',
#        'Children & Family Movies, Comedies, Music & Musicals',
#        'Comedies, Independent Movies', 'Comedies, Horror Movies',
#        'Children & Family Movies, Comedies, Romantic Movies',
#        'Comedies, International Movies, Sports Movies',
#        'Comedies, Cult Movies', 'Stand-Up Comedy',
#        'Comedies, Music & Musicals',
#        'Comedies, International Movies, Sci-Fi & Fantasy',
#        'Children & Family Movies, Comedies, International Movies',
#        'Comedies, International Movies, Thrillers',
#        'Action & Adventure, Comedies, Dramas',
#        'Comedies, Independent Movies, International Movies',
#        'Classic Movies, Comedies, Dramas',
#        'Comedies, International Movies, LGBTQ Movies',
#        'Children & Family Movies, Comedies, Sci-Fi & Fantasy',
#        'Action & Adventure, Classic Movies, Comedies',
#        'Comedies, Cult Movies, Dramas', 'Comedies, Dramas, LGBTQ Movies',
#        'Action & Adventure, Comedies, Cult Movies',
#        'Action & Adventure, Comedies, Sci-Fi & Fantasy',
#        'Action & Adventure, Comedies, Independent Movies',
#        'Comedies, Sports Movies', 'Music & Musicals, Stand-Up Comedy',
#        'Children & Family Movies, Comedies, Dramas',
#        'Children & Family Movies, Classic Movies, Comedies',
#        'Comedies, Faith & Spirituality, Romantic Movies',
#        'Classic Movies, Comedies, International Movies',
#        'Comedies, Sci-Fi & Fantasy',
#        'Comedies, Cult Movies, International Movies',
#        'Comedies, Music & Musicals, Romantic Movies',
#        'Children & Family Movies, Comedies, Faith & Spirituality',
#        'Classic Movies, Comedies, Cult Movies',
#        'Comedies, Dramas, Music & Musicals',
#        'Classic Movies, Comedies, Music & Musicals',
#        'Comedies, Horror Movies, International Movies',
#        'Action & Adventure, Comedies, Romantic Movies',
#        'Comedies, Dramas, Faith & Spirituality',
#        'Comedies, Faith & Spirituality, International Movies',
#        'Comedies, Independent Movies, LGBTQ Movies',
#        'Documentaries, Stand-Up Comedy',
#        'Comedies, Independent Movies, Romantic Movies',
#        'Comedies, Cult Movies, Horror Movies',
#        'Comedies, Cult Movies, Sports Movies',
#        'Comedies, Horror Movies, Independent Movies',
#        'Comedies, Cult Movies, Independent Movies',
#        'Comedies, Documentaries',
#        'Comedies, Independent Movies, Music & Musicals',
#        'Children & Family Movies, Comedies, Cult Movies',
#        'Comedies, Romantic Movies, Sports Movies',
#        'Action & Adventure, Children & Family Movies, Comedies',
#        'Children & Family Movies, Comedies, LGBTQ Movies',
#        'Action & Adventure, Comedies, Music & Musicals',
#        'Children & Family Movies, Comedies, Sports Movies',
#        'Classic Movies, Comedies, Independent Movies',
#        'Classic Movies, Comedies, Romantic Movies',
#        'Comedies, Music & Musicals, Sports Movies',
#        'Classic Movies, Comedies, Sports Movies',
#        'Comedies, Dramas, Sports Movies',
#        'Comedies, LGBTQ Movies, Music & Musicals',
#        'Comedies, Cult Movies, LGBTQ Movies',
#        'Comedies, Horror Movies, Sci-Fi & Fantasy',
#        'Action & Adventure, Comedies, Horror Movies'], dtype=object)

# %% [markdown]
# ### In how many movies or shows Tom Cruise was cast?

# %%
netflix.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico  TV-MA
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore      R
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States  PG-13
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States  PG-13
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
# 2     78 min                Horror Movies, International Movies
# 3     80 min  Action & Adventure, Independent Movies, Sci-Fi...
# 4    123 min                                             Dramas
#
#                                          Description   Date_New  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018
# 3  In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017
# 4  A brilliant group of students become card-coun... 2020-01-01  2020

# %%
netflix[netflix.Cast.str.contains('[Tt]om [Cc]ruise',regex=True,na=False)]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country Rating  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States      R
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States      R
#
#      Duration                        Type  \
# 3860  189 min  Dramas, Independent Movies
# 5071  134 min      Classic Movies, Dramas
#
#                                             Description   Date_New  Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019

# %% [markdown]
# ### What are the different Ratings Defined by Netflix?

# %%
df = pd.DataFrame(netflix.Rating.unique(),columns=['Ratings']).sort_values('Ratings').reset_index(drop=True)

# %%
df.nunique()
# Out:
# Ratings    14
# dtype: int64

# %%
df
# Out:
#      Ratings
# 0          G
# 1      NC-17
# 2         NR
# 3         PG
# 4      PG-13
# 5          R
# 6      TV-14
# 7       TV-G
# 8      TV-MA
# 9      TV-PG
# 10      TV-Y
# 11     TV-Y7
# 12  TV-Y7-FV
# 13        UR
# 14       NaN

# %% [markdown]
# ### How many movies got TV-14 rating in Canada?

# %%
netflix['Show_Id'][(netflix.Rating == 'TV-14') & (netflix.Category == 'Movie') & (netflix.Country == 'Canada')].nunique()
# Out:
# 11

# %% [markdown]
# ### How many TV Shows R rating after 2018?

# %%
netflix[(netflix.Category == 'TV Show') & (netflix.Rating == 'R') & (netflix.Year > '2018')]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Rating  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN      R
#
#       Duration      Type                                        Description  \
# 6437  1 Season  TV Shows  Trapped at a stagecoach stop as a storm rages ...
#
#        Date_New  Year
# 6437 2019-04-25  2019

# %%
netflix['Year'] = netflix.Year.astype('int',errors='ignore')

# %% [markdown]
# ### What is the Maximum duration of movie /Show on Netflix?

# %%
netflix.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Rating  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  TV-MA
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico  TV-MA
#
#     Duration                                               Type  \
# 0  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1     93 min                       Dramas, International Movies
#
#                                          Description   Date_New  Year
# 0  In a future where the elite inhabit an island ... 2020-08-14  2020
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016

# %%
netflix.loc[netflix.Duration.str.contains('Season(s)?',regex=True) == True,'Season/Time'] = 'Total Seasons'
# Out:
# C:\Users\Rhugved\AppData\Local\Temp\ipykernel_9624\1536975531.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   netflix.loc[netflix.Duration.str.contains('Season(s)?',regex=True) == True,'Season/Time'] = 'Total Seasons'

# %%
netflix.loc[netflix.Duration.str.contains('min(s)?',regex=True) == True,'Season/Time'] = 'Movie Duration'
# Out:
# C:\Users\Rhugved\AppData\Local\Temp\ipykernel_9624\1982928106.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   netflix.loc[netflix.Duration.str.contains('min(s)?',regex=True) == True,'Season/Time'] = 'Movie Duration'

# %%
netflix['Period'] = netflix.Duration.str.extract(r'(\d+)').astype('int')

# %%
netflix.groupby('Season/Time').Period.max()
# Out:
# Season/Time
# Movie Duration    312
# Total Seasons      16
# Name: Period, dtype: int64

# %%
netflix.dtypes
# Out:
# Show_Id                object
# Category               object
# Title                  object
# Director               object
# Cast                   object
# Country                object
# Rating                 object
# Duration               object
# Type                   object
# Description            object
# Date_New       datetime64[ns]
# Year                   object
# Season/Time            object
# Period                  int64
# dtype: object

# %%
 netflix[['Seasons/Min','Unit']]=netflix.Duration.str.split(' ',expand=True)

# %%
netflix
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7784        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                NaN                                            Nasty C
# 7787                NaN                         Adriano Zumbo, Rachel Khoo
# 7788           Sam Dunn                                                NaN
#
#                                                 Country Rating   Duration  \
# 0                                                Brazil  TV-MA  4 Seasons
# 1                                                Mexico  TV-MA     93 min
# 2                                             Singapore      R     78 min
# 3                                         United States  PG-13     80 min
# 4                                         United States  PG-13    123 min
# ...                                                 ...    ...        ...
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...  TV-MA     99 min
# 7785                                              India  TV-14    111 min
# 7786                                                NaN  TV-MA     44 min
# 7787                                          Australia  TV-PG   1 Season
# 7788              United Kingdom, Canada, United States  TV-MA     90 min
#
#                                                    Type  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7784                       Dramas, International Movies
# 7785     Dramas, International Movies, Music & Musicals
# 7786  Documentaries, International Movies, Music & M...
# 7787                 International TV Shows, Reality TV
# 7788                    Documentaries, Music & Musicals
#
#                                             Description   Date_New  Year  \
# 0     In a future where the elite inhabit an island ... 2020-08-14  2020
# 1     After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2     When an army recruit is found dead, his fellow... 2018-12-20  2018
# 3     In a postapocalyptic world, rag-doll robots hi... 2017-11-16  2017
# 4     A brilliant group of students become card-coun... 2020-01-01  2020
# ...                                                 ...        ...   ...
# 7784  When Lebanon's Civil War deprives Zozo of his ... 2020-10-19  2020
# 7785  A scrappy but poor boy worms his way into a ty... 2019-03-02  2019
# 7786  In this documentary, South African rapper Nast... 2020-09-25  2020
# 7787  Dessert wizard Adriano Zumbo looks for the nex... 2020-10-31  2020
# 7788  This documentary delves into the mystique behi... 2020-03-01  2020
#
#          Season/Time  Period Seasons/Min     Unit
# 0      Total Seasons       4           4  Seasons
# 1     Movie Duration      93          93      min
# 2     Movie Duration      78          78      min
# 3     Movie Duration      80          80      min
# 4     Movie Duration     123         123      min
# ...              ...     ...         ...      ...
# 7784  Movie Duration      99          99      min
# 7785  Movie Duration     111         111      min
# 7786  Movie Duration      44          44      min
# 7787   Total Seasons       1           1   Season
# 7788  Movie Duration      90          90      min
#
# [7787 rows x 16 columns]

# %% [markdown]
# ### Which individual Country has highest no. of TV Shows?

# %%
netflix[netflix.Category == 'TV Show'].Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# ### Sort the Dataset by Year

# %%
netflix.sort_values('Year',ascending=True)
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 2263   s2264  TV Show                       Frasier                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
# 2288   s2289  TV Show                       Friends                   NaN
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
#
#                                                    Cast        Country Rating  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States  TV-MA
# 1765                                                NaN  United States  TV-MA
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States  TV-MA
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark  TV-MA
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States     NR
# ...                                                 ...            ...    ...
# 2263  Kelsey Grammer, Jane Leeves, David Hyde Pierce...  United States  TV-PG
# 6066  Luke Jurevicius, Craig Behenna, Charlotte Haml...      Australia  TV-Y7
# 2288  Jennifer Aniston, Courteney Cox, Lisa Kudrow, ...  United States  TV-14
# 3374                                      Igor Dmitriev            NaN   TV-Y
# 5138  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...  United States     NR
#
#         Duration                                               Type  \
# 7115      81 min              Dramas, Independent Movies, Thrillers
# 1765    1 Season                       Stand-Up Comedy & Talk Shows
# 5766      29 min                                      Horror Movies
# 3248     104 min                       Dramas, International Movies
# 3840      84 min                         Cult Movies, Horror Movies
# ...          ...                                                ...
# 2263  11 Seasons                     Classic & Cult TV, TV Comedies
# 6066   2 Seasons                              Kids' TV, TV Comedies
# 2288  10 Seasons                     Classic & Cult TV, TV Comedies
# 3374   2 Seasons                                           Kids' TV
# 5138  13 Seasons  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
#
#                                             Description   Date_New  Year  \
# 7115  While covering a story in New York City, a Sea... 2008-01-01  2008
# 1765  In each episode, four celebrities join host Jo... 2008-02-04  2008
# 5766  After committing suicide, a washed-up rocker r... 2009-11-18  2009
# 3248  When he causes a car accident that leaves a yo... 2009-05-05  2009
# 3840  This collection cherry-picks trailers, forgott... 2010-11-01  2010
# ...                                                 ...        ...   ...
# 2263  Frasier Crane is a snooty but lovable Seattle ...        NaT   nan
# 6066  Imagine your worst fears, then multiply them: ...        NaT   nan
# 2288  This hit sitcom follows the merry misadventure...        NaT   nan
# 3374  A wacky rabbit and his gang of animal pals hav...        NaT   nan
# 5138  This parody of first-person shooter games, mil...        NaT   nan
#
#          Season/Time  Period Seasons/Min     Unit
# 7115  Movie Duration      81          81      min
# 1765   Total Seasons       1           1   Season
# 5766  Movie Duration      29          29      min
# 3248  Movie Duration     104         104      min
# 3840  Movie Duration      84          84      min
# ...              ...     ...         ...      ...
# 2263   Total Seasons      11          11  Seasons
# 6066   Total Seasons       2           2  Seasons
# 2288   Total Seasons      10          10  Seasons
# 3374   Total Seasons       2           2  Seasons
# 5138   Total Seasons      13          13  Seasons
#
# [7787 rows x 16 columns]
